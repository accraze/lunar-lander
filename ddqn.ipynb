# %%
import gym, random, tempfile
import numpy as np
from gym import wrappers
import matplotlib.pyplot as plt

from model import build_model
from ddqn import DDQLAgent
# Out:
# Using TensorFlow backend.

# %%
np.set_printoptions(precision=2)

env = gym.make('LunarLander-v2')
env = wrappers.Monitor(env, "./monitor")

num_states = env.observation_space.shape[0]
num_actions = env.action_space.n

# %%
epsilon = 1
epsilon_decay = 0.9993
gamma = 0.99
lr = 0.0001

batch_size = 32
memory_limit=5000

# %%
model = build_model(num_states, num_actions, lr)
target_model = build_model(num_states, num_actions, lr)
print(model.summary())
# Out:
# WARNING:tensorflow:From /Users/accraze/src/lunar-lander/env/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 64)                576
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 260
# ...
# Total params: 4,996
# Trainable params: 4,996
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
agent = DDQLAgent(num_states, num_actions,
                  model=model, lr=lr, gamma=gamma,
                  epsilon=epsilon, epsilon_decay=epsilon_decay, 
                  memory_limit=memory_limit, env=env)

episodes = 3500
history = agent.train(episodes)
# Out:
# WARNING:tensorflow:From /Users/accraze/src/lunar-lander/env/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# episode:  0  score:  -480.74  avg_score:  -480.74  frames:  113  epsilon:  1.00
# episode:  1  score:  -105.44  avg_score:  -293.09  frames:  97  epsilon:  1.00
# episode:  2  score:  -123.81  avg_score:  -236.66  frames:  81  epsilon:  1.00
# episode:  3  score:  -139.08  avg_score:  -212.27  frames:  99  epsilon:  1.00
# episode:  4  score:  -40.80  avg_score:  -177.98  frames:  130  epsilon:  1.00
# episode:  5  score:  -92.37  avg_score:  -163.71  frames:  75  epsilon:  1.00
# episode:  6  score:  -63.14  avg_score:  -149.34  frames:  66  epsilon:  1.00
# episode:  7  score:  -150.05  avg_score:  -149.43  frames:  69  epsilon:  0.99
# ...

# %%
all_rewards_train, epsilon_vals_train, reward_avg_train = history

# %%
def plot(x, key=None, title='Rewards per episode', xlab='', ylab='', multi=False, save=True):
    if multi:
        for _ in x:
            plt.plot(_)
    else:
        plt.plot(x)
    plt.title(title)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    if key is not None:
        plt.legend(key)
    
    plt.show()
    plt.close()
    
plot(all_rewards_train)

# %%
alpha_vals = [0.0001] * len(epsilon_vals_train)
gamma_vals = [0.99] * len(epsilon_vals_train)
plt.plot(epsilon_vals_train, label='epsilon')
plt.plot(alpha_vals, label='alpha = 0.0001')
plt.plot(gamma_vals, label='gamma = 0.99')
plt.title('Hyperparameters per episode')

plt.legend(loc='best')    
plt.show()
plt.close()

# %%
# evaluate the algorithm for 100 episodes.
test_history = agent.test(100)
# Out:
# episode:  0  score:  285.68  avg_score:  285.68  frames:  875  epsilon:  0.09
# episode:  1  score:  240.74  avg_score:  263.21  frames:  166  epsilon:  0.09
# episode:  2  score:  254.98  avg_score:  260.47  frames:  214  epsilon:  0.09
# episode:  3  score:  303.64  avg_score:  271.26  frames:  284  epsilon:  0.09
# episode:  4  score:  213.26  avg_score:  259.66  frames:  478  epsilon:  0.09
# episode:  5  score:  285.46  avg_score:  263.96  frames:  290  epsilon:  0.09
# episode:  6  score:  261.41  avg_score:  263.60  frames:  220  epsilon:  0.09
# episode:  7  score:  217.74  avg_score:  257.86  frames:  352  epsilon:  0.09
# episode:  8  score:  311.64  avg_score:  263.84  frames:  325  epsilon:  0.09
# episode:  9  score:  279.12  avg_score:  265.37  frames:  302  epsilon:  0.09
# episode:  10  score:  285.86  avg_score:  267.23  frames:  645  epsilon:  0.09
# episode:  11  score:  87.98  avg_score:  252.29  frames:  999  epsilon:  0.09
# ...

# %%
plot(test_history[0],  title='Rewards per trial')

# %%
print(test_history[2])
# Out:
# deque([285.6780415393134, 240.74169422650596, 254.9783731686876, 303.6445091412575, 213.25950527715077, 285.4576504476238, 261.4123532298714, 217.7398992674115, 311.6386038471329, 279.1211970429797, 285.8622569373554, 87.98032468946256, 277.9377286037164, 307.60017486413494, 265.5770357608668, -8.04799897607721, 271.99860234431895, 285.60296582172714, 267.8028683859796, 252.59774056101816, 107.98970973928584, 300.9207237717222, 274.1768087771609, 269.4419786723297, 263.84117851990453, 309.3679509413038, 246.09921412824343, 302.81635098409924, 302.2652394394246, 243.83612204707575, 270.8821485796757, 273.5534627899647, 288.2241226668515, 29.026100754556012, 274.55196229222844, 261.3467686263092, 270.48682226730944, 277.7550058828496, 252.65743572084622, 264.84548509058783, 246.6781882718402, 279.37236507717, 269.3416084519069, 281.2841474211177, 269.59966551039344, 277.88164637656075, 250.51885478947156, 285.4066344572964, 257.5094998261769, 280.77875213537504, 254.22253387410802, 249
# ...
